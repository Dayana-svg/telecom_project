# %%
import os 
import pandas as pd 
file_path = "data/telecom_data.csv"
if not os.path.exists("data"):
    print("Ошибка: Папки 'data' не существует! Создайте ее и положите туда файл.")
else:
    print("Папка 'data' найдена.")
# Out:
# Папка 'data' найдена.
